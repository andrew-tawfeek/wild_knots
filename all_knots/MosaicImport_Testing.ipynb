# %%
load("wild_mosaics.py")

# %%
Mosaic([[0, 0, 2, 1, 0, 0, 0],
 [0, 2, 10, 7, 1, 0, 0],
 [2, 10, 9, 10, 10, 1, 0],
 [3, 9, 10, 10, 9, 10, 1],
 [0, 3, 10, 9, 10, 9, 4],
 [0, 0, 3, 9, 10, 4, 0],
 [0, 0, 0, 3, 4, 0, 0]]).show()
# Out:
# Graphics Array of size 7 x 7
