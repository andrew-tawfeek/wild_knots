# %%
load("wild_mosaics.py")

# %%
M = random_mosaic(7); M.show()
# Out:
# Graphics Array of size 7 x 7

# %%
M[1,1] = 0; M; W = Mosaic(M); W.show(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 M[Integer(1),Integer(1)] = Integer(0); M; W = Mosaic(M); W.show(Integer(2))
#
# TypeError: 'Mosaic' object does not support item assignment

# %%
W.potential_tiles(1,1)
# Out:
# [3, 4, 6, 7, 8, 9]
